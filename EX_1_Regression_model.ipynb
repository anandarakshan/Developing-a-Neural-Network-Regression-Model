# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
dataset1 = pd.read_csv('/content/drive/MyDrive/Deep Learning/deep-1.csv')
X = dataset1[['Input']].values
y = dataset1[['Output']].values

# %%
dataset1.head()
# Out:
#    Input  Output
# 0      7       3
# 1     31      17
# 2      9       6
# 3      8      23
# 4     54      45

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=33)

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
# Name:
# Register Number:
class NeuralNet(nn.Module):
  def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(1,8)
        self.fc2 = nn.Linear(8,10)
        self.fc3 = nn.Linear(10,1)
        self.relu = nn.ReLU()
        self.history = {'loss': []}
  def forward(self,x):
    x = self.relu(self.fc1(x))
    x = self.relu(self.fc2(x))
    x = self.fc3(x)
    return x

# %%
# Initialize the Model, Loss Function, and Optimizer
# Write your code here
lig = NeuralNet()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(lig.parameters(),lr=0.001)

# %%
# Name:Ananda Rakshan K V
# Register Number:212223230014
def train_model(ai_brain, X_train, y_train, criterion, optimizer, epochs=2000):
    for epoch in range(epochs):
      optimizer.zero_grad()
      loss = criterion(ai_brain(X_train),y_train)
      loss.backward()
      optimizer.step()
      lig.history['loss'].append(loss.item())
      if epoch % 200 == 0:
          print(f'Epoch [{epoch}/{epochs}], Loss: {loss.item():.6f}')

# %%
train_model(lig, X_train_tensor, y_train_tensor, criterion, optimizer)
# Out:
# Epoch [0/2000], Loss: 1646.828369
# Epoch [200/2000], Loss: 1457.083862
# Epoch [400/2000], Loss: 1086.713623
# Epoch [600/2000], Loss: 626.334106
# Epoch [800/2000], Loss: 288.287537
# Epoch [1000/2000], Loss: 190.063202
# Epoch [1200/2000], Loss: 171.448212
# Epoch [1400/2000], Loss: 148.714081
# Epoch [1600/2000], Loss: 127.209885
# Epoch [1800/2000], Loss: 112.413429

# %%
with torch.no_grad():
    test_loss = criterion(lig(X_test_tensor), y_test_tensor)
    print(f'Test Loss: {test_loss.item():.6f}')
# Out:
# Test Loss: 227.350494

# %%
loss_df = pd.DataFrame(lig.history)

# %%
import matplotlib.pyplot as plt
loss_df.plot()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss during Training")
plt.show()

# %%
X_n1_1 = torch.tensor([[9]], dtype=torch.float32)
prediction = lig(torch.tensor(scaler.transform(X_n1_1), dtype=torch.float32)).item()
print(f'Prediction: {prediction}')
# Out:
# Prediction: 17.352272033691406
